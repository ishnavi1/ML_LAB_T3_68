# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_14076\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
to_drop = ['high_blood_pressure',
           'sex',
           'time',
        ]

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    platelets  serum_creatinine  serum_sodium  smoking  DEATH_EVENT
# 0  265000.00               1.9           130        0            1
# 1  263358.03               1.1           136        0            1
# 2  162000.00               1.3           129        1            1
# 3  210000.00               1.9           137        0            1
# 4  327000.00               2.7           116        0            1

# %%
df['age'].is_unique
# Out:
# False

# %%
df = df.set_index('age')
df.head()
# Out:
#       anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# age
# 75.0        0                       582         0                 20
# 55.0        0                      7861         0                 38
# 65.0        0                       146         0                 20
# 50.0        1                       111         0                 20
# 65.0        1                       160         1                 20
#
#       platelets  serum_creatinine  serum_sodium  smoking  DEATH_EVENT
# age
# 75.0  265000.00               1.9           130        0            1
# 55.0  263358.03               1.1           136        0            1
# 65.0  162000.00               1.3           129        1            1
# 50.0  210000.00               1.9           137        0            1
# 65.0  327000.00               2.7           116        0            1

# %%
df['anaemia'].head(2)
# Out:
# age
# 75.0    0
# 55.0    0
# Name: anaemia, dtype: int64

# %%
df.set_index('platelets', inplace=True)

# %%
df.rename(columns={'serum_creatinine': 'Frequency'})
# Out:
#            anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# platelets
# 265000.00        0                       582         0                 20
# 263358.03        0                      7861         0                 38
# 162000.00        0                       146         0                 20
# 210000.00        1                       111         0                 20
# 327000.00        1                       160         1                 20
# ...            ...                       ...       ...                ...
# 155000.00        0                        61         1                 38
# 270000.00        0                      1820         0                 38
# 742000.00        0                      2060         1                 60
# 140000.00        0                      2413         0                 38
# 395000.00        0                       196         0                 45
#
#            Frequency  serum_sodium  smoking  DEATH_EVENT
# platelets
# ...
